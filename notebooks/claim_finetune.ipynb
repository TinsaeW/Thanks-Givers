# %%
# !pip3 install newspaper3k -Uqq
# !pip install cohere -q
# Out:
#      |████████████████████████████████| 211 kB 5.0 MB/s
#      |████████████████████████████████| 93 kB 2.1 MB/s
#      |████████████████████████████████| 81 kB 9.3 MB/s
#      |████████████████████████████████| 7.4 MB 22.9 MB/s
# ...

# %%
import pandas as pd
from newspaper import Article

# %%
links = ['https://www.cureus.com/articles/111851-regular-use-of-ivermectin-as-prophylaxis-for-covid-19-led-up-to-a-92-reduction-in-covid-19-mortality-rate-in-a-dose-response-manner-results-of-a-prospective-observational-study-of-a-strictly-controlled-population-of-88012-subjects?email_share=true&expedited_modal=true',
         'https://www.thegatewaypundit.com/2022/09/dr-harvey-risch-biggest-lie-last-29-months-covid-pandemic-hydroxychloroquine-hundreds-thousands-died-result-video/',
         'https://www.thegatewaypundit.com/2022/09/ethically-unjustifiable-new-harvard-johns-hopkins-study-found-covid-19-vaccines-98-times-worse-disease/',
         'https://www.theepochtimes.com/exclusive-former-greenpeace-founder-patrick-moore-debunks-the-false-narratives-of-climate-change_4709568.html',
         'http://medicalcrisisdeclaration.com/',
         'https://www.theflstandard.com/massacre-nearly-half-of-pregnant-women-in-pfizer-trial-miscarried/?fbclid=IwAR13tunlEKAOEOTwbAILqOzmYi62lYmvL9_YHhFaSVVd5_UbfwwG7lGTbo8',
         'https://expose-news.com/2022/09/11/government-publishes-figures-on-covid-vaccine-deaths/',
         'https://newspunch.com/klaus-schwabs-wef-plans-to-censor-the-internet-using-ai/',
         'https://www.thegatewaypundit.com/2022/08/bank-america-offer-zero-payment-zero-closing-cost-mortgage-loans-black-hispanic-borrowers/?utm_source=rss&utm_medium=rss&utm_campaign=bank-of-america-to-offer-zero-down-payment-zero-closing-cost-mortgage-loans-to-black-and-hispanic-borrowers',
         'https://www.chinadaily.com.cn/a/202208/23/WS6304c3a3a310fd2b29e73d40.html',
         'https://dailysceptic.org/2022/08/18/1200-scientists-and-professionals-declare-there-is-no-climate-emergency/',
         'https://newspunch.com/wef-announce-recruitment-of-information-warriors-to-control-the-narrative-on-social-media/',
         'https://expose-news.com/2022/07/28/gov-docs-monkeypox-coverup-vaids/?fbclid=IwAR3gcdPfybhCE2-jCbt_Q1stnA-0FKWNxGkxFvyFnDJkxfUkWnOZVLZf0dc',
         'https://www.thegatewaypundit.com/2022/07/breaking-dominion-voting-machiens-fail-el-paso-co-co-logic-accuracy-test-hand-recount/?fbclid=IwAR0VT0lHLlvpepL2-jvBtBto6g1fmY8QBBvVlaLAg4B5Fif2j5lOqYPQtVA',
         'https://www.thegatewaypundit.com/2022/07/shocking-november-4th-2020-georgia-showed-100-reporting-trump-won-250000-ballots-manufactured-biden-given-win-raffensperger-days-later-per-voterga/?fbclid=IwAR2g3JXf5XN11PtJLouII_w5Y0brVLGWHG6Sc0bm7WnVSyFAOrOxzmapriY',
         'https://expose-news.com/2022/07/24/monkeypox-pfizer-great-reset/',
         'https://newspunch.com/michelle-obama-registered-to-vote-as-a-man-in-1994-according-to-illinois-state-board-of-elections/',
         'https://vancouvertimes.org/who-director-arrested-for-crimes-against-humanity/',
         'https://patriotpartypress.com/megan-rapinoe-booted-from-us-team-for-assaulting-a-teammate/',
         'https://expose-news.com/2022/07/11/boris-distraction-uk-gov-revealed-triple-vaccinated-94percent-covid-deaths/',
         'https://www.thegatewaypundit.com/2022/07/huge-data-supporting-final-results-2020-election-not-reconcile-voting-machine-files-something-wrong/',
         'https://newspunch.com/high-ranking-ukrainian-officials-caught-splurging-on-luxury-real-estate-in-switzerland/',
         'https://www.thesun.co.uk/news/19155449/cost-of-living-crisis-number-one-issue-next-pm/',
         'https://www.mirror.co.uk/news/politics/how-much-minister-earn-resigning-27420425',
         'https://newspunch.com/world-economic-forum-to-freeze-bank-accounts-of-meat-eaters-to-educate-them/',
         'https://www.wnd.com/2022/05/inconvenient-truth-globalists-arctic-ice-30-year-high/?fbclid=IwAR2CeYG052P5H1kgKDVpoh4X5ch0XK1jlYX6DLi08dqhxPzVZPS_KIO4on8',
         'https://www.bbc.com/news/uk-61806383',
         'https://newspunch.com/bidens-irs-starts-buying-up-ammunitions-as-biden-vows-to-disarm-ordinary-citizens/',
         'https://www.mirror.co.uk/news/politics/children-feeling-suicidal-down-cost-27275715',
         'https://www.israel365news.com/352994/on-may-22-biden-to-hand-over-american-sovereignty-to-who/',
         'https://expose-news.com/2022/06/11/77k-dead-7million-injured-covid-vaccine-us-uk-eu/',
         'https://vancouvertimes.org/justin-bieber-the-vaccine-ruined-my-life/'

         

         ]

# %%
claims = ['The regular use of ivermectin as prophylaxis for COVID-19 result in up to a 92% reduction in the disease’s mortality rate and also reduces infection and hospitalization',
          'The FDA hid the evidence that HCQ [hydroxychloroquine] was effective in the early treatment of the disease. Hundreds of thousands of people died as a result of this lie',
          'Covid-19 Vaccines 98 Times Worse Than the Virus',
          'CO2 is not the cause of our current warming trend; Arctic sea ice has expanded in recent years; Polar bears’ population is growing and is not threatened by climate change; CO2 is good for plant life.',
          'there is an international medical crisis due to the diseases and deaths co-related to the administration of products known as ‘COVID-19 vaccines',
          '44% of pregnant women in Pfizer Covid 19 vaccine trial had a miscarriage.',
          'England published “horrific figures on COVID Vaccine Deaths” that show 1 in 482 people died within a month of receiving their shot, 1 in 246 died within 60 days and 1 in 73 died by May 2022.',
          'Klaus Schwab’s WEF Plans To Censor the Internet Using AI.',
          'Bank of America announced a new mortgage home loan program for first-time homebuyers. But only blacks and Hispanics will be eligible.',
          'Washington’s weaponizing food hurts world.',
          'Natural variation explains a substantial part of global warming observed since 1850; no statistical evidence that global warming is intensifying natural disasters, or making them more frequent',
          'WEF Announce Recruitment of ‘Information Warriors’ To Control the Narrative on Social Media',
          ' We’re not witnessing an outbreak of monkeypox across first-world countries, but the consequences of the damage that has been caused to immune systems by the Covid-19 vaccines.',
          'Dominion Voting Machines FAIL Testing for Colorado Secretary of State Recount',
          ' In 2020, 250,000 ballots were manufactured in Georgia and Biden was given win by Secretary of State Brad Raffensperger',
          'Public health authorities are attempting to cover up Covid-19 vaccine-induced shingles by calling it monkeypox.',
          'Michelle Obama registered To Vote As A Man according To Illinois State Board of Elections.',
          'WHO director arrested for crimes against humanity.',
          ' Megan Rapinoe Booted From US Team For Assaulting a Teammate.',
          'Data from the Office for National Statistics shows the vaccinated population were suffering immense immune system damage in April and May 2022.',
          'Differences between an election data stream provided by Edison Research and official sources prove “Something Is Very Wrong” with the 2020 election results.',
          'High-ranking Ukrainian officials caught splurging on luxury real estate in Switzerland',
          'Two thirds of asylum-seekers who arrived here since 2018 claiming to be unaccompanied children were found to be adults.',
          'The Prime Minister is not entitled to a ministerial severance payment on leaving office',
          'World Economic Forum Will Freeze Bank Accounts of Meat Eaters To Educate Them, Doconomy Does Enforce Consumer Spending Limit',
          'Arctic sea ice reached a 30-year high in May 2022',
          'The first asylum seeker flight from the UK to Rwanda was stopped by an EU court.',
          'Biden’s IRS Starts Buying Up Ammunitions as Biden Vows to Disarm Ordinary Citizens',
          'One in 10 children have started self-harming',
          'The World Health Organization Will Have Authority To Lock Down All of America.',
          'Throughout Europe, the USA, the UK and Australia, medicine regulators have received reports of 77,068 deaths due to Covid-19 vaccination.',
          'Justin Bieber Said That COVID-19 Vax Ruined His Life.'
          ]
assert len(links)==len(claims)

# %%
len(links)
# Out:
# 32

# %%
full_text = ''
for i in range(len(links)):
  article = Article(links[i])
  article.download()
  article.parse()


  full_text = full_text + 'Article: ' + article.title + ' ' + article.text[:5000] + '\n'*2 + 'Claim: ' + claims[i] + '\n'*2 + '--' + '\n'*2

# %%
print(full_text)
# Out:
# Article: Regular Use of Ivermectin as Prophylaxis for COVID-19 Led Up to a 92% Reduction in COVID-19 Mortality Rate in a Dose-Response Manner: Results of a Prospective Observational Study of a Strictly Control Non-use of ivermectin was associated with a 12.5-fold increase in mortality rate and a seven-fold increased risk of dying from COVID-19 compared to the regular use of ivermectin. This dose-response efficacy reinforces the prophylactic effects of ivermectin against COVID-19.
#
# ...

# %%
text_file = open("training.txt", "w")
text_file.write(full_text)
text_file.close()

# %% [markdown]
# # To use the model

# %%
import cohere
from newspaper import Article

link = 'https://newspunch.com/media-silent-as-nih-study-finds-long-covid-isnt-real/' #news site
article = Article(link)
article.download()
article.parse()


full_text = 'Article: ' + article.title + ' ' + article.text[:5000]  + '\n'*2 + 'Claim: '


co = cohere.Client('') #your API key here
response = co.generate(
  model='66a925fa-41b6-4495-a8ee-54c59fb2b7a2-ft',
  prompt=full_text)
print('Prediction: {}'.format(response.generations[0].text))
# Out:
# Prediction:  Long COVID is a serious physical condition that persists long after recovering from the coronavirus. https://t.
# ...
